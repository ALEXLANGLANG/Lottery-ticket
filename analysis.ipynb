# %%
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
  
# Read Images 
img = mpimg.imread('./plots/lt/fc1/mnist/lt_LossVsAccuracy_100.0.png') 
  
# Output Images 
plt.imshow(img)

# %%
img = mpimg.imread('./plots/lt/fc1/mnist/lt_LossVsAccuracy_90.0.png') 
  
# Output Images 
plt.imshow(img)
